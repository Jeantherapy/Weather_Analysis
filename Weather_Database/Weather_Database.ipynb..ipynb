# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import pandas as pd
import numpy as np
from citipy import citipy
import requests

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 747

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call

# Assemble the API call URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=53c9839f78577ee9f98801465c7a0a7a

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
    
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          "Date": city_date})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass


# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | fairbanks
# Processing Record 2 of Set 1 | bambous virieux
# Processing Record 3 of Set 1 | muktagachha
# City not found. Skipping...
# Processing Record 4 of Set 1 | faya
# Processing Record 5 of Set 1 | bacuit
# City not found. Skipping...
# Processing Record 6 of Set 1 | castro
# Processing Record 7 of Set 1 | east london
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | mandiana
# Processing Record 10 of Set 1 | constitucion
# Processing Record 11 of Set 1 | orbetello
# Processing Record 12 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 13 of Set 1 | flinders
# Processing Record 14 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 1 | bethel
# Processing Record 16 of Set 1 | talnakh
# Processing Record 17 of Set 1 | atuona
# Processing Record 18 of Set 1 | avera
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | tripoli
# Processing Record 21 of Set 1 | aromashevo
# Processing Record 22 of Set 1 | koppa
# Processing Record 23 of Set 1 | kavieng
# Processing Record 24 of Set 1 | saskylakh
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | port elizabeth
# Processing Record 27 of Set 1 | kozhva
# Processing Record 28 of Set 1 | kasungu
# Processing Record 29 of Set 1 | bordighera
# Processing Record 30 of Set 1 | nikolskoye
# Processing Record 31 of Set 1 | ereymentau
# Processing Record 32 of Set 1 | yellowknife
# Processing Record 33 of Set 1 | am timan
# Processing Record 34 of Set 1 | ushuaia
# Processing Record 35 of Set 1 | lodja
# Processing Record 36 of Set 1 | rikitea
# Processing Record 37 of Set 1 | dikson
# Processing Record 38 of Set 1 | kodiak
# Processing Record 39 of Set 1 | naze
# Processing Record 40 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 1 | yibin
# Processing Record 42 of Set 1 | miles city
# Processing Record 43 of Set 1 | zhangjiakou
# Processing Record 44 of Set 1 | vanimo
# Processing Record 45 of Set 1 | mahebourg
# Processing Record 46 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 1 | tamworth
# Processing Record 49 of Set 1 | vacaria
# Processing Record 50 of Set 1 | thinadhoo
# Processing Record 1 of Set 2 | qaanaaq
# Processing Record 2 of Set 2 | mar del plata
# Processing Record 3 of Set 2 | serebryansk
# Processing Record 4 of Set 2 | iskateley
# Processing Record 5 of Set 2 | busselton
# Processing Record 6 of Set 2 | tchibanga
# Processing Record 7 of Set 2 | hobart
# Processing Record 8 of Set 2 | bandarbeyla
# Processing Record 9 of Set 2 | bluff
# Processing Record 10 of Set 2 | saint-philippe
# Processing Record 11 of Set 2 | ilulissat
# Processing Record 12 of Set 2 | tuktoyaktuk
# Processing Record 13 of Set 2 | san vicente
# Processing Record 14 of Set 2 | carnarvon
# Processing Record 15 of Set 2 | coquimbo
# Processing Record 16 of Set 2 | thompson
# Processing Record 17 of Set 2 | alice springs
# Processing Record 18 of Set 2 | yumen
# Processing Record 19 of Set 2 | ponta do sol
# Processing Record 20 of Set 2 | fortuna
# Processing Record 21 of Set 2 | atambua
# Processing Record 22 of Set 2 | new norfolk
# Processing Record 23 of Set 2 | victor harbor
# Processing Record 24 of Set 2 | magadan
# Processing Record 25 of Set 2 | severo-kurilsk
# Processing Record 26 of Set 2 | miracema do tocantins
# Processing Record 27 of Set 2 | barrow
# Processing Record 28 of Set 2 | gazli
# Processing Record 29 of Set 2 | bredasdorp
# Processing Record 30 of Set 2 | bhubaneswar
# Processing Record 31 of Set 2 | rocha
# Processing Record 32 of Set 2 | saldanha
# Processing Record 33 of Set 2 | namatanai
# Processing Record 34 of Set 2 | kitgum
# Processing Record 35 of Set 2 | kapaa
# Processing Record 36 of Set 2 | lompoc
# Processing Record 37 of Set 2 | kieta
# Processing Record 38 of Set 2 | broome
# Processing Record 39 of Set 2 | georgetown
# Processing Record 40 of Set 2 | chuy
# Processing Record 41 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 2 | mango
# Processing Record 43 of Set 2 | sao filipe
# Processing Record 44 of Set 2 | port blair
# Processing Record 45 of Set 2 | lebu
# Processing Record 46 of Set 2 | katsuura
# Processing Record 47 of Set 2 | trapani
# Processing Record 48 of Set 2 | tasiilaq
# Processing Record 49 of Set 2 | norman wells
# Processing Record 50 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 3 | provideniya
# Processing Record 2 of Set 3 | khatanga
# Processing Record 3 of Set 3 | pevek
# Processing Record 4 of Set 3 | coihaique
# Processing Record 5 of Set 3 | kenai
# Processing Record 6 of Set 3 | touros
# Processing Record 7 of Set 3 | bokhan
# Processing Record 8 of Set 3 | berbera
# Processing Record 9 of Set 3 | san cristobal
# Processing Record 10 of Set 3 | ust-omchug
# Processing Record 11 of Set 3 | arlit
# Processing Record 12 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 3 | pacific grove
# Processing Record 14 of Set 3 | narsaq
# Processing Record 15 of Set 3 | labuhan
# Processing Record 16 of Set 3 | sioux lookout
# Processing Record 17 of Set 3 | grand gaube
# Processing Record 18 of Set 3 | chernyshevskiy
# Processing Record 19 of Set 3 | nabire
# Processing Record 20 of Set 3 | kirakira
# Processing Record 21 of Set 3 | presidencia roque saenz pena
# Processing Record 22 of Set 3 | pisco
# Processing Record 23 of Set 3 | hilo
# Processing Record 24 of Set 3 | hounde
# Processing Record 25 of Set 3 | kungurtug
# Processing Record 26 of Set 3 | tual
# Processing Record 27 of Set 3 | kazachinskoye
# Processing Record 28 of Set 3 | cabo san lucas
# Processing Record 29 of Set 3 | vaini
# Processing Record 30 of Set 3 | port alfred
# Processing Record 31 of Set 3 | kuusamo
# Processing Record 32 of Set 3 | hithadhoo
# Processing Record 33 of Set 3 | butaritari
# Processing Record 34 of Set 3 | areosa
# Processing Record 35 of Set 3 | kesinga
# Processing Record 36 of Set 3 | namibe
# Processing Record 37 of Set 3 | nara
# Processing Record 38 of Set 3 | bilma
# Processing Record 39 of Set 3 | lorengau
# Processing Record 40 of Set 3 | dubbo
# Processing Record 41 of Set 3 | puerto ayora
# Processing Record 42 of Set 3 | rafsanjan
# Processing Record 43 of Set 3 | aklavik
# Processing Record 44 of Set 3 | bengkulu
# Processing Record 45 of Set 3 | yanan
# City not found. Skipping...
# Processing Record 46 of Set 3 | reggio di calabria
# Processing Record 47 of Set 3 | faanui
# Processing Record 48 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 49 of Set 3 | shingu
# Processing Record 50 of Set 3 | hare bay
# Processing Record 1 of Set 4 | vila franca do campo
# Processing Record 2 of Set 4 | nanortalik
# Processing Record 3 of Set 4 | zhicheng
# Processing Record 4 of Set 4 | manaure
# Processing Record 5 of Set 4 | takoradi
# Processing Record 6 of Set 4 | chalus
# Processing Record 7 of Set 4 | kitzingen
# Processing Record 8 of Set 4 | tecolutla
# Processing Record 9 of Set 4 | chokurdakh
# Processing Record 10 of Set 4 | mount gambier
# Processing Record 11 of Set 4 | upernavik
# Processing Record 12 of Set 4 | hami
# Processing Record 13 of Set 4 | hermanus
# Processing Record 14 of Set 4 | port augusta
# Processing Record 15 of Set 4 | qui nhon
# Processing Record 16 of Set 4 | manacapuru
# Processing Record 17 of Set 4 | cabedelo
# Processing Record 18 of Set 4 | ostrovnoy
# Processing Record 19 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 4 | jamestown
# Processing Record 21 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 22 of Set 4 | kahului
# Processing Record 23 of Set 4 | puerto escondido
# Processing Record 24 of Set 4 | kokopo
# Processing Record 25 of Set 4 | broken hill
# Processing Record 26 of Set 4 | chapais
# Processing Record 27 of Set 4 | rafai
# Processing Record 28 of Set 4 | rudnichnyy
# Processing Record 29 of Set 4 | cape town
# Processing Record 30 of Set 4 | hualmay
# Processing Record 31 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 4 | cherskiy
# Processing Record 33 of Set 4 | isangel
# Processing Record 34 of Set 4 | hofn
# Processing Record 35 of Set 4 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 36 of Set 4 | miri
# Processing Record 37 of Set 4 | la primavera
# Processing Record 38 of Set 4 | olonets
# Processing Record 39 of Set 4 | sola
# Processing Record 40 of Set 4 | victoria
# Processing Record 41 of Set 4 | kansk
# Processing Record 42 of Set 4 | ribeira grande
# Processing Record 43 of Set 4 | san luis
# Processing Record 44 of Set 4 | green river
# Processing Record 45 of Set 4 | vysokogornyy
# Processing Record 46 of Set 4 | belen
# Processing Record 47 of Set 4 | zhigansk
# Processing Record 48 of Set 4 | totness
# Processing Record 49 of Set 4 | turan
# Processing Record 50 of Set 4 | asau
# Processing Record 1 of Set 5 | mastic beach
# Processing Record 2 of Set 5 | salina
# Processing Record 3 of Set 5 | husavik
# Processing Record 4 of Set 5 | nikki
# Processing Record 5 of Set 5 | otradnoye
# Processing Record 6 of Set 5 | kavaratti
# Processing Record 7 of Set 5 | fort nelson
# Processing Record 8 of Set 5 | saint-augustin
# Processing Record 9 of Set 5 | yasnogorsk
# Processing Record 10 of Set 5 | umba
# Processing Record 11 of Set 5 | swellendam
# Processing Record 12 of Set 5 | nikolayevsk-na-amure
# Processing Record 13 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 5 | gorele
# Processing Record 15 of Set 5 | roma
# Processing Record 16 of Set 5 | vestmannaeyjar
# Processing Record 17 of Set 5 | kisangani
# Processing Record 18 of Set 5 | nemuro
# Processing Record 19 of Set 5 | troy
# Processing Record 20 of Set 5 | ambovombe
# Processing Record 21 of Set 5 | azar shahr
# City not found. Skipping...
# Processing Record 22 of Set 5 | tecoanapa
# Processing Record 23 of Set 5 | sitka
# Processing Record 24 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 5 | tiksi
# Processing Record 26 of Set 5 | solnechnyy
# Processing Record 27 of Set 5 | saint george
# Processing Record 28 of Set 5 | cascais
# Processing Record 29 of Set 5 | corum
# Processing Record 30 of Set 5 | maceio
# Processing Record 31 of Set 5 | bereda
# Processing Record 32 of Set 5 | tuatapere
# Processing Record 33 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 5 | gravdal
# Processing Record 35 of Set 5 | cessnock
# Processing Record 36 of Set 5 | loreto
# Processing Record 37 of Set 5 | baghdad
# Processing Record 38 of Set 5 | bukama
# Processing Record 39 of Set 5 | vagur
# Processing Record 40 of Set 5 | arraial do cabo
# Processing Record 41 of Set 5 | north bend
# Processing Record 42 of Set 5 | porto walter
# Processing Record 43 of Set 5 | coos bay
# Processing Record 44 of Set 5 | alugan
# Processing Record 45 of Set 5 | awbari
# Processing Record 46 of Set 5 | vardo
# Processing Record 47 of Set 5 | rawson
# Processing Record 48 of Set 5 | maarianhamina
# Processing Record 49 of Set 5 | houma
# Processing Record 50 of Set 5 | aras
# Processing Record 1 of Set 6 | agadez
# Processing Record 2 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 6 | codrington
# Processing Record 4 of Set 6 | srednekolymsk
# Processing Record 5 of Set 6 | sabha
# Processing Record 6 of Set 6 | praia
# Processing Record 7 of Set 6 | tiruchchendur
# Processing Record 8 of Set 6 | bowen
# Processing Record 9 of Set 6 | san patricio
# Processing Record 10 of Set 6 | gilgit
# Processing Record 11 of Set 6 | beroroha
# Processing Record 12 of Set 6 | farah
# Processing Record 13 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 6 | leningradskiy
# Processing Record 15 of Set 6 | antofagasta
# Processing Record 16 of Set 6 | mehamn
# Processing Record 17 of Set 6 | langxiang
# Processing Record 18 of Set 6 | palaiokhora
# City not found. Skipping...
# Processing Record 19 of Set 6 | springbok
# Processing Record 20 of Set 6 | samarai
# Processing Record 21 of Set 6 | salalah
# Processing Record 22 of Set 6 | dujuma
# City not found. Skipping...
# Processing Record 23 of Set 6 | ponca city
# Processing Record 24 of Set 6 | tigil
# Processing Record 25 of Set 6 | viedma
# Processing Record 26 of Set 6 | khash
# Processing Record 27 of Set 6 | basco
# Processing Record 28 of Set 6 | hobyo
# Processing Record 29 of Set 6 | acapulco
# Processing Record 30 of Set 6 | khani
# Processing Record 31 of Set 6 | bonavista
# Processing Record 32 of Set 6 | wulanhaote
# City not found. Skipping...
# Processing Record 33 of Set 6 | wodonga
# Processing Record 34 of Set 6 | marsh harbour
# Processing Record 35 of Set 6 | oparino
# Processing Record 36 of Set 6 | salinopolis
# Processing Record 37 of Set 6 | morros
# Processing Record 38 of Set 6 | harper
# Processing Record 39 of Set 6 | airai
# Processing Record 40 of Set 6 | moose factory
# Processing Record 41 of Set 6 | arman
# Processing Record 42 of Set 6 | brainerd
# Processing Record 43 of Set 6 | berlevag
# Processing Record 44 of Set 6 | nome
# Processing Record 45 of Set 6 | vitoria do mearim
# Processing Record 46 of Set 6 | churapcha
# Processing Record 47 of Set 6 | kudahuvadhoo
# Processing Record 48 of Set 6 | lucapa
# Processing Record 49 of Set 6 | half moon bay
# Processing Record 50 of Set 6 | klaksvik
# Processing Record 1 of Set 7 | zaigrayevo
# Processing Record 2 of Set 7 | dingle
# Processing Record 3 of Set 7 | zanjan
# Processing Record 4 of Set 7 | novo cruzeiro
# Processing Record 5 of Set 7 | payo
# Processing Record 6 of Set 7 | avarua
# Processing Record 7 of Set 7 | mount pleasant
# Processing Record 8 of Set 7 | longyearbyen
# Processing Record 9 of Set 7 | chenzhou
# Processing Record 10 of Set 7 | ranong
# Processing Record 11 of Set 7 | sinnamary
# Processing Record 12 of Set 7 | cayenne
# Processing Record 13 of Set 7 | geraldton
# Processing Record 14 of Set 7 | jinchang
# Processing Record 15 of Set 7 | stokmarknes
# Processing Record 16 of Set 7 | bairnsdale
# Processing Record 17 of Set 7 | college
# Processing Record 18 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 19 of Set 7 | sao jose da coroa grande
# Processing Record 20 of Set 7 | yelets
# Processing Record 21 of Set 7 | tautira
# Processing Record 22 of Set 7 | jucuaran
# Processing Record 23 of Set 7 | coahuayana
# Processing Record 24 of Set 7 | gornyy
# Processing Record 25 of Set 7 | kipushi
# Processing Record 26 of Set 7 | kaitangata
# Processing Record 27 of Set 7 | zenzeli
# Processing Record 28 of Set 7 | zachagansk
# City not found. Skipping...
# Processing Record 29 of Set 7 | guelengdeng
# City not found. Skipping...
# Processing Record 30 of Set 7 | svetlogorsk
# Processing Record 31 of Set 7 | toftir
# City not found. Skipping...
# Processing Record 32 of Set 7 | mahanoro
# Processing Record 33 of Set 7 | taltal
# Processing Record 34 of Set 7 | do rud
# City not found. Skipping...
# Processing Record 35 of Set 7 | billings
# Processing Record 36 of Set 7 | itarema
# Processing Record 37 of Set 7 | campo grande
# Processing Record 38 of Set 7 | manica
# Processing Record 39 of Set 7 | santa maria
# Processing Record 40 of Set 7 | carutapera
# Processing Record 41 of Set 7 | vila velha
# Processing Record 42 of Set 7 | biak
# Processing Record 43 of Set 7 | mawlaik
# Processing Record 44 of Set 7 | okha
# Processing Record 45 of Set 7 | christchurch
# Processing Record 46 of Set 7 | temaraia
# City not found. Skipping...
# Processing Record 47 of Set 7 | eydhafushi
# Processing Record 48 of Set 7 | puri
# Processing Record 49 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 7 | ocampo
# Processing Record 1 of Set 8 | meridian
# Processing Record 2 of Set 8 | palmeirais
# Processing Record 3 of Set 8 | abu jubayhah
# City not found. Skipping...
# Processing Record 4 of Set 8 | kargasok
# Processing Record 5 of Set 8 | mende
# Processing Record 6 of Set 8 | lata
# Processing Record 7 of Set 8 | filingue
# Processing Record 8 of Set 8 | romny
# Processing Record 9 of Set 8 | oriximina
# Processing Record 10 of Set 8 | molchanovo
# Processing Record 11 of Set 8 | skagen
# Processing Record 12 of Set 8 | camacha
# Processing Record 13 of Set 8 | hanzhong
# Processing Record 14 of Set 8 | dale
# Processing Record 15 of Set 8 | iqaluit
# Processing Record 16 of Set 8 | pascagoula
# Processing Record 17 of Set 8 | yarkovo
# Processing Record 18 of Set 8 | tolaga bay
# Processing Record 19 of Set 8 | okhotsk
# Processing Record 20 of Set 8 | chumikan
# Processing Record 21 of Set 8 | ancud
# Processing Record 22 of Set 8 | mazagao
# Processing Record 23 of Set 8 | mogocha
# Processing Record 24 of Set 8 | lagoa
# Processing Record 25 of Set 8 | adrar
# Processing Record 26 of Set 8 | rincon
# Processing Record 27 of Set 8 | motygino
# Processing Record 28 of Set 8 | pokhara
# Processing Record 29 of Set 8 | ubata
# Processing Record 30 of Set 8 | hasaki
# Processing Record 31 of Set 8 | virovitica
# Processing Record 32 of Set 8 | stornoway
# Processing Record 33 of Set 8 | manzil tamim
# City not found. Skipping...
# Processing Record 34 of Set 8 | khodz
# Processing Record 35 of Set 8 | general roca
# Processing Record 36 of Set 8 | jaleswar
# Processing Record 37 of Set 8 | sarmanovo
# Processing Record 38 of Set 8 | sisimiut
# Processing Record 39 of Set 8 | aripuana
# Processing Record 40 of Set 8 | saint-pierre
# Processing Record 41 of Set 8 | odweyne
# Processing Record 42 of Set 8 | dharchula
# Processing Record 43 of Set 8 | high rock
# Processing Record 44 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 45 of Set 8 | poum
# Processing Record 46 of Set 8 | aswan
# Processing Record 47 of Set 8 | tommot
# Processing Record 48 of Set 8 | ixtapa
# Processing Record 49 of Set 8 | itaituba
# Processing Record 50 of Set 8 | wanning
# Processing Record 1 of Set 9 | roald
# Processing Record 2 of Set 9 | torbay
# Processing Record 3 of Set 9 | fairview
# Processing Record 4 of Set 9 | huanren
# Processing Record 5 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 6 of Set 9 | pangody
# Processing Record 7 of Set 9 | monatele
# City not found. Skipping...
# Processing Record 8 of Set 9 | guarda
# Processing Record 9 of Set 9 | muravlenko
# Processing Record 10 of Set 9 | esperance
# Processing Record 11 of Set 9 | quatre cocos
# Processing Record 12 of Set 9 | maksatikha
# Processing Record 13 of Set 9 | beringovskiy
# Processing Record 14 of Set 9 | tiarei
# Processing Record 15 of Set 9 | moranbah
# Processing Record 16 of Set 9 | nioaque
# Processing Record 17 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 18 of Set 9 | port-cartier
# Processing Record 19 of Set 9 | guerrero negro
# Processing Record 20 of Set 9 | solwezi
# Processing Record 21 of Set 9 | mopti
# Processing Record 22 of Set 9 | tingi
# Processing Record 23 of Set 9 | singida
# Processing Record 24 of Set 9 | laguna
# Processing Record 25 of Set 9 | romanovka
# Processing Record 26 of Set 9 | statesboro
# Processing Record 27 of Set 9 | kishi
# Processing Record 28 of Set 9 | turtkul
# City not found. Skipping...
# Processing Record 29 of Set 9 | baykit
# Processing Record 30 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 31 of Set 9 | sept-iles
# Processing Record 32 of Set 9 | kruisfontein
# Processing Record 33 of Set 9 | chupa
# Processing Record 34 of Set 9 | bathsheba
# Processing Record 35 of Set 9 | maxixe
# Processing Record 36 of Set 9 | rio gallegos
# Processing Record 37 of Set 9 | souillac
# Processing Record 38 of Set 9 | minab
# Processing Record 39 of Set 9 | ranau
# Processing Record 40 of Set 9 | nosy varika
# Processing Record 41 of Set 9 | obera
# Processing Record 42 of Set 9 | folkestone
# Processing Record 43 of Set 9 | koungheul
# Processing Record 44 of Set 9 | monte cristi
# City not found. Skipping...
# Processing Record 45 of Set 9 | nakusp
# Processing Record 46 of Set 9 | verkhnyaya toyma
# Processing Record 47 of Set 9 | usinsk
# Processing Record 48 of Set 9 | kolosovka
# Processing Record 49 of Set 9 | xai-xai
# Processing Record 50 of Set 9 | punta alta
# Processing Record 1 of Set 10 | los llanos de aridane
# Processing Record 2 of Set 10 | ariquemes
# Processing Record 3 of Set 10 | andevoranto
# City not found. Skipping...
# Processing Record 4 of Set 10 | tazovskiy
# Processing Record 5 of Set 10 | port hawkesbury
# Processing Record 6 of Set 10 | bundaberg
# Processing Record 7 of Set 10 | katobu
# Processing Record 8 of Set 10 | oceanside
# Processing Record 9 of Set 10 | marzuq
# Processing Record 10 of Set 10 | zaysan
# Processing Record 11 of Set 10 | hailey
# Processing Record 12 of Set 10 | bandar-e lengeh
# Processing Record 13 of Set 10 | khormuj
# City not found. Skipping...
# Processing Record 14 of Set 10 | buraydah
# Processing Record 15 of Set 10 | padang
# Processing Record 16 of Set 10 | eldorado
# Processing Record 17 of Set 10 | bullhead city
# Processing Record 18 of Set 10 | celestun
# Processing Record 19 of Set 10 | morant bay
# Processing Record 20 of Set 10 | rosarito
# Processing Record 21 of Set 10 | ossora
# Processing Record 22 of Set 10 | xuchang
# Processing Record 23 of Set 10 | vestmanna
# Processing Record 24 of Set 10 | khed brahma
# Processing Record 25 of Set 10 | rocky mountain house
# Processing Record 26 of Set 10 | amurrio
# Processing Record 27 of Set 10 | port macquarie
# Processing Record 28 of Set 10 | keti bandar
# Processing Record 29 of Set 10 | shahr-e kord
# Processing Record 30 of Set 10 | catia la mar
# Processing Record 31 of Set 10 | filadelfia
# Processing Record 32 of Set 10 | nishihara
# Processing Record 33 of Set 10 | anloga
# Processing Record 34 of Set 10 | wajima
# Processing Record 35 of Set 10 | dalvik
# Processing Record 36 of Set 10 | bristol
# Processing Record 37 of Set 10 | ucluelet
# Processing Record 38 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 39 of Set 10 | cockburn harbour
# City not found. Skipping...
# Processing Record 40 of Set 10 | muros
# Processing Record 41 of Set 10 | eppingen
# Processing Record 42 of Set 10 | vrangel
# Processing Record 43 of Set 10 | germenchik
# Processing Record 44 of Set 10 | werda
# Processing Record 45 of Set 10 | wattegama
# Processing Record 46 of Set 10 | lumding
# Processing Record 47 of Set 10 | pafos
# Processing Record 48 of Set 10 | haines junction
# Processing Record 49 of Set 10 | portree
# Processing Record 50 of Set 10 | bergerac
# Processing Record 1 of Set 11 | araouane
# Processing Record 2 of Set 11 | praia da vitoria
# Processing Record 3 of Set 11 | strezhevoy
# Processing Record 4 of Set 11 | zlatoustovsk
# City not found. Skipping...
# Processing Record 5 of Set 11 | kloulklubed
# Processing Record 6 of Set 11 | calatayud
# Processing Record 7 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 8 of Set 11 | valparaiso
# Processing Record 9 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 10 of Set 11 | russell
# Processing Record 11 of Set 11 | ustek
# Processing Record 12 of Set 11 | alpena
# Processing Record 13 of Set 11 | axim
# Processing Record 14 of Set 11 | gondanglegi
# Processing Record 15 of Set 11 | galich
# Processing Record 16 of Set 11 | uray
# Processing Record 17 of Set 11 | zhangye
# Processing Record 18 of Set 11 | korla
# Processing Record 19 of Set 11 | mao
# Processing Record 20 of Set 11 | cap malheureux
# Processing Record 21 of Set 11 | banjar
# Processing Record 22 of Set 11 | ajaccio
# Processing Record 23 of Set 11 | manuk mangkaw
# Processing Record 24 of Set 11 | santa rita
# Processing Record 25 of Set 11 | uusikaupunki
# Processing Record 26 of Set 11 | new cumnock
# Processing Record 27 of Set 11 | cabadiangan
# Processing Record 28 of Set 11 | nuuk
# Processing Record 29 of Set 11 | terney
# Processing Record 30 of Set 11 | balabac
# Processing Record 31 of Set 11 | belaya gora
# Processing Record 32 of Set 11 | ngunguru
# Processing Record 33 of Set 11 | san angelo
# Processing Record 34 of Set 11 | santa rita do passa quatro
# Processing Record 35 of Set 11 | banda aceh
# Processing Record 36 of Set 11 | hamilton
# Processing Record 37 of Set 11 | yar-sale
# Processing Record 38 of Set 11 | maldonado
# Processing Record 39 of Set 11 | zapolyarnyy
# Processing Record 40 of Set 11 | clyde river
# Processing Record 41 of Set 11 | masunga
# Processing Record 42 of Set 11 | isabela
# Processing Record 43 of Set 11 | pratapgarh
# Processing Record 44 of Set 11 | iaciara
# Processing Record 45 of Set 11 | urumqi
# Processing Record 46 of Set 11 | bahia blanca
# Processing Record 47 of Set 11 | alta floresta
# Processing Record 48 of Set 11 | praya
# Processing Record 49 of Set 11 | ahuimanu
# Processing Record 50 of Set 11 | amalapuram
# Processing Record 1 of Set 12 | glendive
# Processing Record 2 of Set 12 | ilhabela
# Processing Record 3 of Set 12 | crab hill
# City not found. Skipping...
# Processing Record 4 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 12 | bafra
# Processing Record 6 of Set 12 | krionerion
# City not found. Skipping...
# Processing Record 7 of Set 12 | worland
# Processing Record 8 of Set 12 | bonfim
# Processing Record 9 of Set 12 | zimmi
# Processing Record 10 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 11 of Set 12 | merauke
# Processing Record 12 of Set 12 | nguruka
# Processing Record 13 of Set 12 | mpongwe
# Processing Record 14 of Set 12 | la asuncion
# Processing Record 15 of Set 12 | nicoya
# Processing Record 16 of Set 12 | vao
# Processing Record 17 of Set 12 | lebork
# Processing Record 18 of Set 12 | kindu
# Processing Record 19 of Set 12 | deputatskiy
# Processing Record 20 of Set 12 | altamont
# Processing Record 21 of Set 12 | batemans bay
# Processing Record 22 of Set 12 | vanavara
# Processing Record 23 of Set 12 | martapura
# Processing Record 24 of Set 12 | suntar
# Processing Record 25 of Set 12 | denpasar
# Processing Record 26 of Set 12 | khonsa
# Processing Record 27 of Set 12 | ouro preto do oeste
# Processing Record 28 of Set 12 | baillif
# Processing Record 29 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 30 of Set 12 | iglesias
# Processing Record 31 of Set 12 | makakilo city
# Processing Record 32 of Set 12 | bardiyah
# Processing Record 33 of Set 12 | elesbao veloso
# Processing Record 34 of Set 12 | lasa
# Processing Record 35 of Set 12 | sinnai
# Processing Record 36 of Set 12 | capoterra
# Processing Record 37 of Set 12 | pochutla
# Processing Record 38 of Set 12 | sheopur
# Processing Record 39 of Set 12 | ambulu
# Processing Record 40 of Set 12 | lagos
# Processing Record 41 of Set 12 | bonthe
# Processing Record 42 of Set 12 | ihosy
# Processing Record 43 of Set 12 | tshikapa
# Processing Record 44 of Set 12 | tillabery
# City not found. Skipping...
# Processing Record 45 of Set 12 | beloha
# Processing Record 46 of Set 12 | tura
# Processing Record 47 of Set 12 | katha
# City not found. Skipping...
# Processing Record 48 of Set 12 | palmer
# Processing Record 49 of Set 12 | oktyabrskoye
# Processing Record 50 of Set 12 | barmer
# Processing Record 1 of Set 13 | hovd
# Processing Record 2 of Set 13 | wucheng
# Processing Record 3 of Set 13 | sabrum
# Processing Record 4 of Set 13 | sorland
# Processing Record 5 of Set 13 | visnes
# Processing Record 6 of Set 13 | xining
# Processing Record 7 of Set 13 | belluru
# Processing Record 8 of Set 13 | sosnovo-ozerskoye
# Processing Record 9 of Set 13 | dhuburi
# Processing Record 10 of Set 13 | grand forks
# Processing Record 11 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 13 | howard springs
# Processing Record 13 of Set 13 | dagda
# Processing Record 14 of Set 13 | sao felix do xingu
# Processing Record 15 of Set 13 | santa rosa
# Processing Record 16 of Set 13 | mmathubudukwane
# Processing Record 17 of Set 13 | dudinka
# Processing Record 18 of Set 13 | guatire
# Processing Record 19 of Set 13 | ayagoz
# Processing Record 20 of Set 13 | cidreira
# Processing Record 21 of Set 13 | beyneu
# Processing Record 22 of Set 13 | kuandian
# Processing Record 23 of Set 13 | onalaska
# Processing Record 24 of Set 13 | teguldet
# Processing Record 25 of Set 13 | shablykino
# Processing Record 26 of Set 13 | lavrentiya
# Processing Record 27 of Set 13 | dovolnoye
# Processing Record 28 of Set 13 | henties bay
# Processing Record 29 of Set 13 | albacete
# Processing Record 30 of Set 13 | cliffside park
# Processing Record 31 of Set 13 | manggar
# Processing Record 32 of Set 13 | maracas
# Processing Record 33 of Set 13 | lixourion
# Processing Record 34 of Set 13 | sechura
# Processing Record 35 of Set 13 | leh
# Processing Record 36 of Set 13 | santiago
# Processing Record 37 of Set 13 | yelan
# Processing Record 38 of Set 13 | la libertad
# Processing Record 39 of Set 13 | natchitoches
# Processing Record 40 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 41 of Set 13 | nikolayevka
# Processing Record 42 of Set 13 | gizo
# Processing Record 43 of Set 13 | polunochnoye
# Processing Record 44 of Set 13 | la ronge
# Processing Record 45 of Set 13 | aykhal
# Processing Record 46 of Set 13 | smithers
# Processing Record 47 of Set 13 | byron bay
# Processing Record 48 of Set 13 | amapa
# Processing Record 49 of Set 13 | kautokeino
# Processing Record 50 of Set 13 | leshukonskoye
# Processing Record 1 of Set 14 | lazaro cardenas
# Processing Record 2 of Set 14 | dicabisagan
# Processing Record 3 of Set 14 | inhambane
# Processing Record 4 of Set 14 | banamba
# Processing Record 5 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 6 of Set 14 | xiaoshan
# Processing Record 7 of Set 14 | gazanjyk
# Processing Record 8 of Set 14 | svetlaya
# Processing Record 9 of Set 14 | yomitan
# City not found. Skipping...
# Processing Record 10 of Set 14 | potoci
# Processing Record 11 of Set 14 | ambon
# Processing Record 12 of Set 14 | orizona
# Processing Record 13 of Set 14 | yulara
# Processing Record 14 of Set 14 | lima
# Processing Record 15 of Set 14 | snezhnogorsk
# Processing Record 16 of Set 14 | urucara
# Processing Record 17 of Set 14 | kondoa
# Processing Record 18 of Set 14 | banyo
# Processing Record 19 of Set 14 | fuerte olimpo
# Processing Record 20 of Set 14 | cururupu
# Processing Record 21 of Set 14 | inderborskiy
# City not found. Skipping...
# Processing Record 22 of Set 14 | mareeba
# Processing Record 23 of Set 14 | belaya kholunitsa
# Processing Record 24 of Set 14 | yagodnoye
# Processing Record 25 of Set 14 | gunnedah
# Processing Record 26 of Set 14 | arti
# Processing Record 27 of Set 14 | murgab
# Processing Record 28 of Set 14 | tuy hoa
# Processing Record 29 of Set 14 | shipunovo
# Processing Record 30 of Set 14 | dumas
# Processing Record 31 of Set 14 | dukat
# Processing Record 32 of Set 14 | guaruja
# Processing Record 33 of Set 14 | pangnirtung
# Processing Record 34 of Set 14 | anar darreh
# City not found. Skipping...
# Processing Record 35 of Set 14 | forbes
# Processing Record 36 of Set 14 | laranjeiras do sul
# Processing Record 37 of Set 14 | carmen
# Processing Record 38 of Set 14 | goteborg
# City not found. Skipping...
# Processing Record 39 of Set 14 | bubaque
# Processing Record 40 of Set 14 | ternova
# Processing Record 41 of Set 14 | dingli
# Processing Record 42 of Set 14 | barentu
# Processing Record 43 of Set 14 | kandrian
# Processing Record 44 of Set 14 | parras
# City not found. Skipping...
# Processing Record 45 of Set 14 | corn island
# Processing Record 46 of Set 14 | rovaniemi
# Processing Record 47 of Set 14 | sofiysk
# City not found. Skipping...
# Processing Record 48 of Set 14 | mwinilunga
# Processing Record 49 of Set 14 | kirovskiy
# Processing Record 50 of Set 14 | beruni
# City not found. Skipping...
# Processing Record 1 of Set 15 | tarko-sale
# Processing Record 2 of Set 15 | holme
# Processing Record 3 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 4 of Set 15 | seydi
# Processing Record 5 of Set 15 | da lat
# Processing Record 6 of Set 15 | male
# Processing Record 7 of Set 15 | zabid
# Processing Record 8 of Set 15 | tanout
# Processing Record 9 of Set 15 | dmitrovsk-orlovskiy
# Processing Record 10 of Set 15 | sur
# Processing Record 11 of Set 15 | mullaitivu
# City not found. Skipping...
# Processing Record 12 of Set 15 | amahai
# Processing Record 13 of Set 15 | kaputa
# Processing Record 14 of Set 15 | lushoto
# Processing Record 15 of Set 15 | kysyl-syr
# Processing Record 16 of Set 15 | ayan
# Processing Record 17 of Set 15 | dunedin
# Processing Record 18 of Set 15 | mogok
# Processing Record 19 of Set 15 | weihai
# Processing Record 20 of Set 15 | hrubieszow
# Processing Record 21 of Set 15 | ampanihy
# Processing Record 22 of Set 15 | umm kaddadah
# Processing Record 23 of Set 15 | ojinaga
# Processing Record 24 of Set 15 | high level
# Processing Record 25 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 26 of Set 15 | ippy
# Processing Record 27 of Set 15 | muisne
# Processing Record 28 of Set 15 | bouna
# Processing Record 29 of Set 15 | muroto
# Processing Record 30 of Set 15 | poso
# Processing Record 31 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 32 of Set 15 | hambantota
# Processing Record 33 of Set 15 | chemal
# Processing Record 34 of Set 15 | agbor
# Processing Record 35 of Set 15 | hit
# Processing Record 36 of Set 15 | charters towers
# Processing Record 37 of Set 15 | nouakchott
# Processing Record 38 of Set 15 | karambakkudi
# Processing Record 39 of Set 15 | taloqan
# Processing Record 40 of Set 15 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 15 | karratha
# Processing Record 42 of Set 15 | belmonte
# Processing Record 43 of Set 15 | prince rupert
# Processing Record 44 of Set 15 | dongsheng
# Processing Record 45 of Set 15 | tarnova
# Processing Record 46 of Set 15 | el retorno
# Processing Record 47 of Set 15 | nkan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 677

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# Display the DataFrame
city_data_df
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Fairbanks  64.8378 -147.7164     63.09        59           0
# 1    Bambous Virieux -20.3428   57.7575     75.45        73          20
# 2               Faya  18.3851   42.4509     70.32        59          90
# 3             Castro -24.7911  -50.0119     72.52        49           0
# 4        East London -33.0153   27.9116     54.54        82           0
# ..               ...      ...       ...       ...       ...         ...
# 672    Prince Rupert  54.3161 -130.3201     51.89        92         100
# 673        Dongsheng  39.8161  109.9776     63.73        25          41
# 674          Tarnova  46.3167   21.8000     69.75        80          15
# 675       El Retorno   2.3302  -72.6276     86.88        58          40
# 676             Nkan   0.3833    9.7833     79.65        78          86
#
#      Wind Speed Country Current Description                 Date
# 0          6.91      US           clear sky  2023-06-10 17:10:25
# 1          9.22      MU          few clouds  2023-06-10 17:12:51
# 2          0.85      SA     overcast clouds  2023-06-10 17:12:24
# 3          9.48      BR           clear sky  2023-06-10 17:12:52
# 4          5.75      ZA           clear sky  2023-06-10 17:12:52
# ..          ...     ...                 ...                  ...
# 672       19.57      CA     overcast clouds  2023-06-10 17:14:09
# 673       14.99      CN    scattered clouds  2023-06-10 17:09:47
# 674        1.63      RO          light rain  2023-06-10 17:14:09
# 675        3.74      CO    scattered clouds  2023-06-10 17:14:09
# 676        6.62      GA     overcast clouds  2023-06-10 17:14:09
#
# [677 rows x 10 columns]

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Fairbanks  64.8378 -147.7164     63.09        59           0
# 1  Bambous Virieux -20.3428   57.7575     75.45        73          20
# 2             Faya  18.3851   42.4509     70.32        59          90
# 3           Castro -24.7911  -50.0119     72.52        49           0
# 4      East London -33.0153   27.9116     54.54        82           0
# 5           Albany  42.6001  -73.9662     72.18        57          28
# 6         Mandiana  10.6333   -8.6833     91.13        43          43
# 7     Constitucion -35.3333  -72.4167     55.49        51           1
# 8        Orbetello  42.4408   11.2196     73.35        72           5
# 9         Flinders -34.5833  150.8552     50.05        79           0
#
#    Wind Speed Country Current Description                 Date
# 0        6.91      US           clear sky  2023-06-10 17:10:25
# 1        9.22      MU          few clouds  2023-06-10 17:12:51
# 2        0.85      SA     overcast clouds  2023-06-10 17:12:24
# 3        9.48      BR           clear sky  2023-06-10 17:12:52
# 4        5.75      ZA           clear sky  2023-06-10 17:12:52
# 5        7.40      US    scattered clouds  2023-06-10 17:12:50
# 6        3.13      GN          light rain  2023-06-10 17:12:52
# 7       15.26      CL           clear sky  2023-06-10 17:12:52
# 8        6.44      IT           clear sky  2023-06-10 17:11:31
# 9        1.99      AU           clear sky  2023-06-10 17:12:52

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description', 'Date'],
#       dtype='object')

# %%
# Reorder the column order
column_order = ["City", "Country", "Lat","Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description", "Date"]
# Reorder the columns in the DataFrame
city_data_df = city_data_df[column_order]

# Display sample data
city_data_df
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0          Fairbanks      US  64.8378 -147.7164     63.09        59
# 1    Bambous Virieux      MU -20.3428   57.7575     75.45        73
# 2               Faya      SA  18.3851   42.4509     70.32        59
# 3             Castro      BR -24.7911  -50.0119     72.52        49
# 4        East London      ZA -33.0153   27.9116     54.54        82
# ..               ...     ...      ...       ...       ...       ...
# 672    Prince Rupert      CA  54.3161 -130.3201     51.89        92
# 673        Dongsheng      CN  39.8161  109.9776     63.73        25
# 674          Tarnova      RO  46.3167   21.8000     69.75        80
# 675       El Retorno      CO   2.3302  -72.6276     86.88        58
# 676             Nkan      GA   0.3833    9.7833     79.65        78
#
#      Cloudiness  Wind Speed Current Description                 Date
# 0             0        6.91           clear sky  2023-06-10 17:10:25
# 1            20        9.22          few clouds  2023-06-10 17:12:51
# 2            90        0.85     overcast clouds  2023-06-10 17:12:24
# 3             0        9.48           clear sky  2023-06-10 17:12:52
# 4             0        5.75           clear sky  2023-06-10 17:12:52
# ..          ...         ...                 ...                  ...
# 672         100       19.57     overcast clouds  2023-06-10 17:14:09
# 673          41       14.99    scattered clouds  2023-06-10 17:09:47
# 674          15        1.63          light rain  2023-06-10 17:14:09
# 675          40        3.74    scattered clouds  2023-06-10 17:14:09
# 676          86        6.62     overcast clouds  2023-06-10 17:14:09
#
# [677 rows x 10 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# Date                    object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv("WeatherPy_Database.csv", index=False)
